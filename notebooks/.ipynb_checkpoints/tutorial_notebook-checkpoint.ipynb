# %%
# %load_ext autoreload
import trafpy.generator as tpg

# %%
# %autoreload
_ = tpg.gen_skewnorm_val_dist(location=50, skew=-2, scale=10, return_data=True, show_fig=True, num_bins=15)

# %%
# %autoreload
endpoints = ['server_'+str(i) for i in range(5)]
node_dist, fig = tpg.gen_uniform_node_dist(eps=endpoints,show_fig=True)
# Out:
# Src-dst edge weights in chord diagram are all the same, leading to 0 rescaled values. Decrease chord_edge_display_threshold to ensure a range of edge values are included in the chord diagram.

# %%
# %autoreload
node_dist, fig = tpg.gen_multimodal_node_dist(eps=endpoints,skewed_nodes=['server_2'],show_fig=True)

# %%
# %autoreload
node_dist, fig = tpg.gen_multimodal_node_pair_dist(eps=endpoints, skewed_pairs=[['server_1','server_3'], ['server_4','server_2']], show_fig=True)

# %%
# %autoreload
net = tpg.gen_fat_tree(k=4)
fig = tpg.plot_network(net, draw_node_labels=True, network_node_size=1000)
# net = tpg.gen_arbitrary_network(num_eps=10)
print('Racks dict:\n{}'.format(net.graph['rack_to_ep_dict']))
# Out:
# Racks dict:
# {'rack_0': ['server_0', 'server_1', 'server_2', 'server_3'], 'rack_1': ['server_4', 'server_5', 'server_6', 'server_7'], 'rack_2': ['server_8', 'server_9', 'server_10', 'server_11'], 'rack_3': ['server_12', 'server_13', 'server_14', 'server_15']}

# %%
# %autoreload
rack_prob_config = {'racks_dict': net.graph['rack_to_ep_dict'], 'prob_inter_rack': 0.05}
node_dist, _ = tpg.gen_uniform_node_dist(net.graph['endpoints'], rack_prob_config=rack_prob_config, show_fig=True, print_data=False)
# Out:
# Src-dst edge weights in chord diagram are all the same, leading to 0 rescaled values. Decrease chord_edge_display_threshold to ensure a range of edge values are included in the chord diagram.

# %%
# %autoreload
rack_prob_config = {'racks_dict': net.graph['rack_to_ep_dict'], 'prob_inter_rack': 0.9}
node_dist , _ = tpg.gen_uniform_node_dist(net.graph['endpoints'], rack_prob_config=rack_prob_config, show_fig=True, print_data=False)

# %%
# %autoreload
import trafpy.generator as tpg
from trafpy.benchmarker import Benchmark

import math

class DefaultBenchmark(Benchmark):
    def __init__(self, benchmark_name='university', benchmark_version='v001', load_prev_dists=True):
        super(DefaultBenchmark, self).__init__(benchmark_name, benchmark_version, load_prev_dists)

    def get_node_dist(self, eps, racks_dict=None, dist_name='node_dist'):
        dist, path = super().get_node_dist(eps, racks_dict, dist_name)
        if dist is None or not self.load_prev_dists:
            num_skewed_nodes = math.ceil(0.2 * len(eps))
            skewed_node_probs = [0.55/num_skewed_nodes for _ in range(num_skewed_nodes)]
            if racks_dict is None:
                rack_prob_config = None
            else:
                rack_prob_config = {'racks_dict': racks_dict, 'prob_inter_rack': 0.7}
            dist = tpg.gen_multimodal_node_dist(eps, 
                                                rack_prob_config=rack_prob_config, 
                                                num_skewed_nodes=num_skewed_nodes, 
                                                skewed_node_probs=skewed_node_probs, 
                                                show_fig=False, 
                                                print_data=False)
            super().save_dist(dist, dist_name)
        return dist

    def get_interarrival_time_dist(self, dist_name='interarrival_time_dist'):
        dist, path = super().get_interarrival_time_dist(dist_name)
        if dist is None or not self.load_prev_dists:
            dist = tpg.gen_named_val_dist(dist='weibull',
                                            params={'_alpha': 0.9, '_lambda': 6000},
                                            min_val=1,
                                            round_to_nearest=25,
                                            show_fig=False,
                                            print_data=False)
            super().save_dist(dist, dist_name)
        return dist

    def get_flow_size_dist(self, dist_name='flow_size_dist'):
        dist, path = super().get_flow_size_dist(dist_name)
        if dist is None or not self.load_prev_dists:
            dist = tpg.gen_named_val_dist(dist='lognormal',
                                            params={'_mu': 7, '_sigma': 2.5},
                                            min_val=1,
                                            max_val=2e7,
                                            round_to_nearest=25,
                                            show_fig=False,
                                            print_data=False)
            super().save_dist(dist, dist_name)
        return dist


# temp for checking if this works
benchmark = DefaultBenchmark(benchmark_name='university_test', benchmark_version='v001', load_prev_dists=False)

net = tpg.gen_fat_tree(k=4)
node_dist = benchmark.get_node_dist(net.graph['endpoints'], racks_dict=None, dist_name='node_dist')
interarrival_time_dist = benchmark.get_interarrival_time_dist(dist_name='interarrival_time_dist')
flow_size_dist = benchmark.get_flow_size_dist(dist_name='flow_size_dist')
# Out:
# Set to save benchmark university_test distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university_test/
# Saved node_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university_test/
# Saved interarrival_time_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university_test/
# Saved flow_size_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university_test/

# %%
# %autoreload
from trafpy.benchmarker import BenchmarkImporter

net = tpg.gen_fat_tree(k=4)
importer = BenchmarkImporter(benchmark_version='v001', load_prev_dists=False)
print(importer.default_benchmark_names)
dcn_dists = {}
for dcn in ['university', 'private_enterprise', 'commercial_cloud', 'social_media_cloud']:
    dcn_dists[dcn] = importer.get_benchmark_dists(benchmark_name=dcn, eps=net.graph['endpoints'])
# Out:
# load_prev_dist=False. Will re-generate dists with given network params and override any previously saved distributions.
# ['commercial_cloud', 'private_enterprise', 'social_media_cloud', 'university']
# Set to save benchmark university distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/
# Saved node_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/
# Saved flow_size_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/
# Saved interarrival_time_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/
# Set to save benchmark private_enterprise distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/
# Saved node_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/
# Saved flow_size_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/
# Saved interarrival_time_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/
# Set to save benchmark commercial_cloud distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/
# Saved node_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/
# Saved flow_size_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/
# Saved interarrival_time_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/
# Set to save benchmark social_media_cloud distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/
# Saved node_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/
# Saved flow_size_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/
# Saved interarrival_time_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/

# %%
# %autoreload
from trafpy.benchmarker import BenchmarkImporter

net = tpg.gen_fat_tree(k=4)
importer = BenchmarkImporter(benchmark_version='v001', load_prev_dists=False)
print(importer.default_benchmark_names)
dcn_dists = {}
for dcn in ['skewed_nodes_sensitivity_{}'.format(i) for i in ['0', '005', '01', '02', '04']]:
    dcn_dists[dcn] = importer.get_benchmark_dists(benchmark_name=dcn, eps=net.graph['endpoints'])
# Out:
# load_prev_dist=False. Will re-generate dists with given network params and override any previously saved distributions.
# ['commercial_cloud', 'private_enterprise', 'skewed_nodes_sensitivity_0', 'skewed_nodes_sensitivity_005', 'skewed_nodes_sensitivity_01', 'skewed_nodes_sensitivity_02', 'skewed_nodes_sensitivity_04', 'social_media_cloud', 'uniform', 'university']
# Set to save benchmark skewed_nodes_sensitivity_0 distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0/
# Saved node_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0/
# Saved flow_size_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0/
# Saved interarrival_time_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0/
# Set to save benchmark skewed_nodes_sensitivity_005 distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_005/
# Saved node_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_005/
# Saved flow_size_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_005/
# Saved interarrival_time_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_005/
# Set to save benchmark skewed_nodes_sensitivity_01 distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_01/
# Saved node_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_01/
# Saved flow_size_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_01/
# Saved interarrival_time_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_01/
# Set to save benchmark skewed_nodes_sensitivity_02 distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_02/
# Saved node_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_02/
# Saved flow_size_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_02/
# Saved interarrival_time_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_02/
# Set to save benchmark skewed_nodes_sensitivity_04 distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_04/
# Saved node_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_04/
# Saved flow_size_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_04/
# Saved interarrival_time_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_04/

# %%
# %autoreload
from trafpy.benchmarker import BenchmarkImporter

net = tpg.gen_fat_tree(k=6)
importer = BenchmarkImporter(benchmark_version='v001', load_prev_dists=False)
print(importer.default_benchmark_names)
dcn_dists = {}
for dcn in ['rack_sensitivity_{}'.format(i) for i in ['0', '02', '04', '06', '08']]:
#     if dcn == 'rack_sensitivity_02':
    dcn_dists[dcn] = importer.get_benchmark_dists(benchmark_name=dcn, eps=net.graph['endpoints'], racks_dict=net.graph['rack_to_ep_dict'])
# Out:
# load_prev_dist=False. Will re-generate dists with given network params and override any previously saved distributions.
# ['commercial_cloud', 'jobcentric_prototyping', 'private_enterprise', 'rack_sensitivity_0', 'rack_sensitivity_02', 'rack_sensitivity_04', 'rack_sensitivity_06', 'rack_sensitivity_08', 'skewed_nodes_sensitivity_0', 'skewed_nodes_sensitivity_005', 'skewed_nodes_sensitivity_01', 'skewed_nodes_sensitivity_02', 'skewed_nodes_sensitivity_04', 'social_media_cloud', 'tensorflow', 'uniform', 'university']
# Set to save benchmark rack_sensitivity_0 distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_0/
# Saved node_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_0/
# Saved flow_size_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_0/
# Saved interarrival_time_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_0/
# Set to save benchmark rack_sensitivity_02 distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_02/
# Saved node_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_02/
# Saved flow_size_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_02/
# Saved interarrival_time_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_02/
# Set to save benchmark rack_sensitivity_04 distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_04/
# Saved node_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_04/
# Saved flow_size_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_04/
# Saved interarrival_time_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_04/
# Set to save benchmark rack_sensitivity_06 distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_06/
# Saved node_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_06/
# Saved flow_size_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_06/
# Saved interarrival_time_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_06/
# Set to save benchmark rack_sensitivity_08 distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_08/
# Saved node_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_08/
# Saved flow_size_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_08/
# Saved interarrival_time_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_sensitivity_08/

# %%
print(dcn_dists['rack_sensitivity_02']['node_dist'])
# Out:
# [[0.         0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.         0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.         0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.         0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.         0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.         0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.         0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.         0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.         0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.         0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.         0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.         0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.         0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.        ]]

# %%
# %autoreload
from trafpy.benchmarker import BenchmarkImporter

net = tpg.gen_fat_tree(k=4)
importer = BenchmarkImporter(benchmark_version='v001', load_prev_dists=False)
print(importer.default_benchmark_names)
dcn_dists = {}
for dcn in ['jobcentric_prototyping', 'tensorflow']:
    dcn_dists[dcn] = importer.get_benchmark_dists(benchmark_name=dcn, eps=net.graph['endpoints'], racks_dict=net.graph['rack_to_ep_dict'])
# Out:
# load_prev_dist=False. Will re-generate dists with given network params and override any previously saved distributions.
# ['commercial_cloud', 'jobcentric_prototyping', 'private_enterprise', 'rack_sensitivity_0', 'rack_sensitivity_02', 'rack_sensitivity_04', 'rack_sensitivity_06', 'rack_sensitivity_08', 'skewed_nodes_sensitivity_0', 'skewed_nodes_sensitivity_005', 'skewed_nodes_sensitivity_01', 'skewed_nodes_sensitivity_02', 'skewed_nodes_sensitivity_04', 'social_media_cloud', 'tensorflow', 'uniform', 'university']
# Set to save benchmark jobcentric_prototyping distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/jobcentric_prototyping/
# Saved node_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/jobcentric_prototyping/
# Saved flow_size_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/jobcentric_prototyping/
# Saved interarrival_time_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/jobcentric_prototyping/
# Set to save benchmark tensorflow distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/tensorflow/
# Saved node_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/tensorflow/
# Saved flow_size_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/tensorflow/
# Saved interarrival_time_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/tensorflow/

# %%
# %autoreload
import trafpy.generator as tpg
from trafpy.benchmarker import Benchmark


class MyBenchmark(Benchmark):
    def __init__(self, benchmark_name='my_benchmark', benchmark_version='v001', load_prev_dists=True):
        super(MyBenchmark, self).__init__(benchmark_name, benchmark_version, load_prev_dists)

    def get_node_dist(self, eps, racks_dict=None, dist_name='node_dist'):
        dist, path = super().get_node_dist(eps, racks_dict, dist_name)
        if dist is None or not self.load_prev_dists:
            dist = tpg.gen_uniform_node_dist(eps, show_fig=False, print_data=False)
            super().save_dist(dist, dist_name)
        return dist

    def get_interarrival_time_dist(self, dist_name='interarrival_time_dist'):
        dist, path = super().get_interarrival_time_dist(dist_name)
        if dist is None or not self.load_prev_dists:
            dist = {10: 1}
            super().save_dist(dist, dist_name)
        return dist

    def get_flow_size_dist(self, dist_name='flow_size_dist'):
        dist, path = super().get_flow_size_dist(dist_name)
        if dist is None or not self.load_prev_dists:
            dist = {1: 1}
            super().save_dist(dist, dist_name)
        return dist


# temp for checking if this works
benchmark = MyBenchmark(benchmark_name='my_benchmark', benchmark_version='v001', load_prev_dists=False)

net = tpg.gen_fat_tree(k=4)
node_dist = benchmark.get_node_dist(net.graph['endpoints'], racks_dict=None, dist_name='node_dist')
interarrival_time_dist = benchmark.get_interarrival_time_dist(dist_name='interarrival_time_dist')
flow_size_dist = benchmark.get_flow_size_dist(dist_name='flow_size_dist')
# Out:
# Set to save benchmark my_benchmark distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/my_benchmark/
# Saved node_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/my_benchmark/
# Saved interarrival_time_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/my_benchmark/
# Saved flow_size_dist distribution data to /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/my_benchmark/

# %%
print(node_dist)
print(interarrival_time_dist)
print(flow_size_dist)
# Out:
# [[0.         0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.         0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.         0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.         0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.         0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.         0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.         0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.         0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.         0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.         0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.
#   0.00416667 0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.         0.00416667 0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.         0.00416667 0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.         0.00416667]
#  [0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.00416667 0.00416667 0.00416667
#   0.00416667 0.00416667 0.00416667 0.        ]]
# {10: 1}
# {1: 1}

# %%
print(importer.default_benchmark_names)
# Out:
# ['commercial_cloud', 'jobcentric_prototyping', 'private_enterprise', 'rack_sensitivity_0', 'rack_sensitivity_02', 'rack_sensitivity_04', 'rack_sensitivity_06', 'rack_sensitivity_08', 'skewed_nodes_sensitivity_0', 'skewed_nodes_sensitivity_005', 'skewed_nodes_sensitivity_01', 'skewed_nodes_sensitivity_02', 'skewed_nodes_sensitivity_04', 'social_media_cloud', 'tensorflow', 'uniform', 'university']

# %%
from trafpy.benchmarker import BenchmarkImporter

importer = BenchmarkImporter(benchmark_version='v001', load_prev_dists=False)
net = tpg.gen_fat_tree(k=4)
print(net.graph.keys())
dists = importer.get_benchmark_dists(benchmark_name='my_default_benchmark', eps=net.graph['endpoints'], racks_dict=net.graph['rack_to_ep_dict'])
# Out:
# load_prev_dist=False. Will re-generate dists with given network params and override any previously saved distributions.
# dict_keys(['endpoints', 'endpoint_label', 'num_channels_per_link', 'ep_link_capacity', 'ep_link_port_capacity', 'max_nw_capacity', 'curr_nw_capacity_used', 'num_active_connections', 'total_connections_blocked', 'node_labels', 'topology_type', 'channel_names', 'rack_to_ep_dict', 'ep_to_rack_dict'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-8f6cb04e098f> in <module>
#       4 net = tpg.gen_fat_tree(k=4)
#       5 print(net.graph.keys())
# ----> 6 dists = importer.get_benchmark_dists(benchmark_name='my_default_benchmark', eps=net.graph['endpoints'], rack_dist=net.graph['rack_to_ep_dict'])
#
# TypeError: get_benchmark_dists() got an unexpected keyword argument 'rack_dist'
