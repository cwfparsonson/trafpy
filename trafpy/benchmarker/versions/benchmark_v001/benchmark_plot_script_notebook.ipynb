# %%
# %load_ext autoreload
from trafpy.benchmarker.versions.benchmark_v001.distribution_generator import DistributionGenerator

import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload
distgen = DistributionGenerator(load_prev_dists=True)
# plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['uniform', 'university', 'private_enterprise', 'commercial_cloud', 'social_media_cloud'])
plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['university', 'private_enterprise', 'commercial_cloud', 'social_media_cloud'])
# Out:
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/node_dist.json: 0.0018448829650878906 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/interarrival_time_dist.json: 0.023080110549926758 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/flow_size_dist.json: 0.022756099700927734 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/node_dist.json: 0.0010733604431152344 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/interarrival_time_dist.json: 0.0013682842254638672 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/flow_size_dist.json: 0.005480527877807617 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/node_dist.json: 0.0009016990661621094 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/interarrival_time_dist.json: 0.0010082721710205078 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/flow_size_dist.json: 0.005006551742553711 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/node_dist.json: 0.0011749267578125 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/interarrival_time_dist.json: 0.0024967193603515625 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/flow_size_dist.json: 0.010199308395385742 s

# %%
print(plots)
for _class in plots.keys():
    for _dist in plots[_class].keys():
        fig = plots[_class][_dist]
        plt.draw()
        print(type(fig))

plt.show()
# Out:
# {'university': {'node_dist': <matplotlib.image.AxesImage object at 0x7f8698c06f40>, 'interarrival_time_dist': <Figure size 720x1080 with 2 Axes>, 'flow_size_dist': <Figure size 720x1080 with 2 Axes>}, 'private_enterprise': {'node_dist': <matplotlib.image.AxesImage object at 0x7f869888ea00>, 'interarrival_time_dist': <Figure size 720x1080 with 2 Axes>, 'flow_size_dist': <Figure size 720x1080 with 2 Axes>}, 'commercial_cloud': {'node_dist': <matplotlib.image.AxesImage object at 0x7f86983926a0>, 'interarrival_time_dist': <Figure size 720x1080 with 2 Axes>, 'flow_size_dist': <Figure size 720x1080 with 2 Axes>}, 'social_media_cloud': {'node_dist': <matplotlib.image.AxesImage object at 0x7f86981ba340>, 'interarrival_time_dist': <Figure size 720x1080 with 2 Axes>, 'flow_size_dist': <Figure size 720x1080 with 2 Axes>}}
# <class 'matplotlib.image.AxesImage'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.image.AxesImage'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.image.AxesImage'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.image.AxesImage'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>

# %%
print(dists)
