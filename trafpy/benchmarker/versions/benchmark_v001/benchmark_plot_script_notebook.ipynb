# %%
from trafpy.benchmarker.versions.benchmark_v001.distribution_generator import DistributionGenerator

import matplotlib.pyplot as plt

# %%
distgen = DistributionGenerator(load_prev_dists=True)
plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['uniform', 'university', 'private_enterprise', 'commercial_cloud', 'social_media_cloud'])
# Out:
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/node_dist.json: 0.002053499221801758 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/interarrival_time_dist.json: 0.009803295135498047 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/flow_size_dist.json: 0.008285999298095703 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/node_dist.json: 0.0015485286712646484 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/interarrival_time_dist.json: 0.012829780578613281 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/flow_size_dist.json: 0.009388446807861328 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/node_dist.json: 0.0013496875762939453 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/interarrival_time_dist.json: 0.018302440643310547 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/flow_size_dist.json: 0.01714611053466797 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/node_dist.json: 0.001957416534423828 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/interarrival_time_dist.json: 0.04313802719116211 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/flow_size_dist.json: 0.014910221099853516 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/node_dist.json: 0.0018787384033203125 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/interarrival_time_dist.json: 0.014778852462768555 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/flow_size_dist.json: 0.027547597885131836 s

# %%
print(plots)
for _class in plots.keys():
    for _dist in plots[_class].keys():
        fig = plots[_class][_dist]
        plt.draw()
        print(type(fig))

plt.show()

# %%
print(dists)
