# %%
# %load_ext autoreload
from trafpy.benchmarker.versions.benchmark_v001.distribution_generator import DistributionGenerator

import matplotlib.pyplot as plt

# %%
# %autoreload
import config

distgen = DistributionGenerator(load_prev_dists=True)
for benchmark in config.ALL_BENCHMARK_SETS:
    print(benchmark)
# plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['university', 'private_enterprise', 'commercial_cloud', 'social_media_cloud'])
# plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['commercial_cloud'])
# plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=config.ALL_BENCHMARK_SETS)
# plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['skewed_nodes_sensitivity_{}'.format(i) for i in [0, 0.05, 0.1, 0.2, 0.4]])
plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['rack_dist_sensitivity_{}'.format(i) for i in [0.2, 0.4, 0.6, 0.8]])
# Out:
# university
# private_enterprise
# commercial_cloud
# social_media_cloud
# uniform
# artificial_light
# skewed_nodes_sensitivity_0
# skewed_nodes_sensitivity_0.05
# skewed_nodes_sensitivity_0.1
# skewed_nodes_sensitivity_0.2
# skewed_nodes_sensitivity_0.4
# rack_dist_sensitivity_0
# rack_dist_sensitivity_0.2
# rack_dist_sensitivity_0.4
# rack_dist_sensitivity_0.6
# rack_dist_sensitivity_0.8
# jobcentric_prototyping
# tensorflow
# Loading previously saved benchmark dists from /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.2/node_dist.json
# Time to load data from /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.2/node_dist.json: 0.00045037269592285156 s
# ...

# %%
print(plots)
for _class in plots.keys():
    for _dist in plots[_class].keys():
        fig = plots[_class][_dist]
        plt.draw()
        print(type(fig))

plt.show()
# Out:
# {'university': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28f31015e0>, <nxviz.plots.CircosPlot object at 0x7f28f31566d0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'private_enterprise': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28f30e5eb0>, <nxviz.plots.CircosPlot object at 0x7f28f0e68d60>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'commercial_cloud': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28ef920d60>, <nxviz.plots.CircosPlot object at 0x7f28ef814cd0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'social_media_cloud': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28ef30da00>, <nxviz.plots.CircosPlot object at 0x7f28ef190fd0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': 
# ...

# %%
print(dists)
