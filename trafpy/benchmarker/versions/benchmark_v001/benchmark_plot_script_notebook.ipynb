# %%
# %load_ext autoreload
import trafpy
import config
import matplotlib.pyplot as plt

for benchmark in config.get_default_benchmark_names():
    print(benchmark)

plots, dists, rand_vars = config.plot_benchmark_dists(benchmark_names=['university', 'private_enterprise', 'commercial_cloud', 'social_media_cloud'])
# plots, dists, rand_vars = config.plot_benchmark_dists(benchmark_names=config.config.get_default_benchmark_names())
# plots, dists, rand_vars = config.plot_benchmark_dists(benchmark_names=['skewed_nodes_sensitivity_{}'.format(i) for i in ['0', '005', '01', '02', '04']])
# plots, dists, rand_vars = config.plot_benchmark_dists(benchmark_names=['rack_sensitivity_{}'.format(i) for i in ['0', '02', '04', '06', '08']])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# commercial_cloud
# jobcentric_prototyping
# private_enterprise
# rack_sensitivity_0
# rack_sensitivity_02
# rack_sensitivity_04
# rack_sensitivity_06
# rack_sensitivity_08
# skewed_nodes_sensitivity_0
# skewed_nodes_sensitivity_005
# skewed_nodes_sensitivity_01
# skewed_nodes_sensitivity_02
# skewed_nodes_sensitivity_04
# social_media_cloud
# tensorflow
# uniform
# university
#
# ~* university *~
# Set to load benchmark university distribution data from /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/
# Loaded node_dist distribution data from /home/cwfparsonson/Insync/zciccwf@ucl.ac.uk/OneDriveBiz/ipes_cdt/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/node_dist.json
# ...

# %%
print(plots)
for _class in plots.keys():
    for _dist in plots[_class].keys():
        fig = plots[_class][_dist]
        plt.draw()
        print(type(fig))

plt.show()
# Out:
# {'rack_sensitivity_0': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f4e22548090>], 'interarrival_time_dist': <Figure size 620x400 with 2 Axes>, 'flow_size_dist': <Figure size 620x400 with 2 Axes>, 'num_ops_dist': None}, 'rack_sensitivity_02': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f4e2162d290>], 'interarrival_time_dist': <Figure size 620x400 with 2 Axes>, 'flow_size_dist': <Figure size 620x400 with 2 Axes>, 'num_ops_dist': None}, 'rack_sensitivity_04': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f4e2032d0d0>], 'interarrival_time_dist': <Figure size 620x400 with 2 Axes>, 'flow_size_dist': <Figure size 620x400 with 2 Axes>, 'num_ops_dist': None}, 'rack_sensitivity_06': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f4e1fe6ad90>], 'interarrival_time_dist': <Figure size 620x400 with 2 Axes>, 'flow_size_dist': <Figure size 620x400 with 2 Axes>, 'num_ops_dist': None}, 'rack_sensitivity_08': {'node_dist': [<matplotlib.image.AxesImage object a
# ...

# %%
print(dists)
# Out:
# {'rack_sensitivity_0': {'node_dist': array([[0.        , 0.00181159, 0.00181159, 0.00181159, 0.00181159,
#         0.00181159, 0.00181159, 0.00181159, 0.00181159, 0.00181159,
#         0.00181159, 0.00181159, 0.00181159, 0.00181159, 0.00181159,
#         0.00181159, 0.00181159, 0.00181159, 0.00181159, 0.00181159,
#         0.00181159, 0.00181159, 0.00181159, 0.00181159],
#        [0.00181159, 0.        , 0.00181159, 0.00181159, 0.00181159,
#         0.00181159, 0.00181159, 0.00181159, 0.00181159, 0.00181159,
#         0.00181159, 0.00181159, 0.00181159, 0.00181159, 0.00181159,
#         0.00181159, 0.00181159, 0.00181159, 0.00181159, 0.00181159,
#         0.00181159, 0.00181159, 0.00181159, 0.00181159],
#        [0.00181159, 0.00181159, 0.        , 0.00181159, 0.00181159,
#         0.00181159, 0.00181159, 0.00181159, 0.00181159, 0.00181159,
#         0.00181159, 0.00181159, 0.00181159, 0.00181159, 0.00181159,
#         0.00181159, 0.00181159, 0.00181159, 0.00181159, 0.00181159,
# ...
