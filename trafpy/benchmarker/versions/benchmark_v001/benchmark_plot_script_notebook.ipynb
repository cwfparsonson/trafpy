# %%
# %load_ext autoreload
from trafpy.benchmarker.versions.benchmark_v001.distribution_generator import DistributionGenerator

import matplotlib.pyplot as plt

# %%
# %autoreload
import config

distgen = DistributionGenerator(load_prev_dists=True)
for benchmark in config.ALL_BENCHMARK_SETS:
    print(benchmark)
plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['university', 'private_enterprise', 'commercial_cloud', 'social_media_cloud'])
# plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=config.ALL_BENCHMARK_SETS)
# plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['skewed_nodes_sensitivity_{}'.format(i) for i in [0, 0.05, 0.1, 0.2, 0.4]])
# plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['rack_dist_sensitivity_{}'.format(i) for i in [0.2, 0.4, 0.6, 0.8]])
# Out:
# university
# private_enterprise
# commercial_cloud
# social_media_cloud
# uniform
# artificial_light
# skewed_nodes_sensitivity_0
# skewed_nodes_sensitivity_0.05
# skewed_nodes_sensitivity_0.1
# skewed_nodes_sensitivity_0.2
# skewed_nodes_sensitivity_0.4
# rack_dist_sensitivity_0
# rack_dist_sensitivity_0.2
# rack_dist_sensitivity_0.4
# rack_dist_sensitivity_0.6
# rack_dist_sensitivity_0.8
# jobcentric_prototyping
# tensorflow
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/node_dist.json: 0.006506681442260742 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/interarrival_time_dist.json: 0.008126974105834961 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/flow_size_dist.json: 0.009013652801513672 s
# num_ops_dist distribution not previously saved in /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/num_ops_dist.json.
# Dist num_ops_dist for benchmark university not found in /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/num_ops_dist.json. Ensure dist is named as one of ['node_dist', 'interarrival_time_dist', 'flow_size_dist', 'num_ops_dist'], and that dist has been saved in correct location.
# Unrecognised dist_name num_ops_dist
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/node_dist.json: 0.0339052677154541 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/interarrival_time_dist.json: 0.025301456451416016 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/flow_size_dist.json: 0.03911542892456055 s
# num_ops_dist distribution not previously saved in /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/num_ops_dist.json.
# Dist num_ops_dist for benchmark private_enterprise not found in /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/private_enterprise/num_ops_dist.json. Ensure dist is named as one of ['node_dist', 'interarrival_time_dist', 'flow_size_dist', 'num_ops_dist'], and that dist has been saved in correct location.
# Unrecognised dist_name num_ops_dist
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/node_dist.json: 0.020235061645507812 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/interarrival_time_dist.json: 0.0062444210052490234 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/flow_size_dist.json: 0.037963151931762695 s
# num_ops_dist distribution not previously saved in /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/num_ops_dist.json.
# Dist num_ops_dist for benchmark commercial_cloud not found in /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/commercial_cloud/num_ops_dist.json. Ensure dist is named as one of ['node_dist', 'interarrival_time_dist', 'flow_size_dist', 'num_ops_dist'], and that dist has been saved in correct location.
# Unrecognised dist_name num_ops_dist
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/node_dist.json: 0.04824423789978027 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/interarrival_time_dist.json: 0.05707955360412598 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/flow_size_dist.json: 0.05721902847290039 s
# num_ops_dist distribution not previously saved in /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/num_ops_dist.json.
# Dist num_ops_dist for benchmark social_media_cloud not found in /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/social_media_cloud/num_ops_dist.json. Ensure dist is named as one of ['node_dist', 'interarrival_time_dist', 'flow_size_dist', 'num_ops_dist'], and that dist has been saved in correct location.
# Unrecognised dist_name num_ops_dist

# %%
print(plots)
for _class in plots.keys():
    for _dist in plots[_class].keys():
        fig = plots[_class][_dist]
        plt.draw()
        print(type(fig))

plt.show()
# Out:
# {'university': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28f31015e0>, <nxviz.plots.CircosPlot object at 0x7f28f31566d0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'private_enterprise': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28f30e5eb0>, <nxviz.plots.CircosPlot object at 0x7f28f0e68d60>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'commercial_cloud': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28ef920d60>, <nxviz.plots.CircosPlot object at 0x7f28ef814cd0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'social_media_cloud': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28ef30da00>, <nxviz.plots.CircosPlot object at 0x7f28ef190fd0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'skewed_nodes_sensitivity_0.4': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28eee6bb20>, <nxviz.plots.CircosPlot object at 0x7f28eee599a0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}}
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>

# %%
print(dists)
