# %%
# %load_ext autoreload
from trafpy.benchmarker.versions.benchmark_v001.distribution_generator import DistributionGenerator

import matplotlib.pyplot as plt

# %%
# %autoreload
import config

distgen = DistributionGenerator(load_prev_dists=True)
# plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['uniform', 'university', 'private_enterprise', 'commercial_cloud', 'social_media_cloud'])
for benchmark in config.ALL_BENCHMARK_SETS:
    print(benchmark)
# plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=config.ALL_BENCHMARK_SETS)
# plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['skewed_nodes_sensitivity_{}'.format(i) for i in [0, 0.05, 0.1, 0.2, 0.4]])
plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['rack_dist_sensitivity_{}'.format(i) for i in [0.2, 0.4, 0.6, 0.8]])
# Out:
# university
# private_enterprise
# commercial_cloud
# social_media_cloud
# uniform
# artificial_light
# skewed_nodes_sensitivity_0
# skewed_nodes_sensitivity_0.05
# skewed_nodes_sensitivity_0.1
# skewed_nodes_sensitivity_0.2
# skewed_nodes_sensitivity_0.4
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0/node_dist.json: 0.0011527538299560547 s
# Src-dst edge weights in chord diagram are all the same, leading to 0 rescaled values. Decrease chord_edge_display_threshold to ensure a range of edge values are included in the chord diagram.
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0/interarrival_time_dist.json: 0.0011756420135498047 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0/flow_size_dist.json: 0.016491413116455078 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.05/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.05/node_dist.json: 0.002861499786376953 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.05/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.05/interarrival_time_dist.json: 0.002688169479370117 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.05/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.05/flow_size_dist.json: 0.03385567665100098 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.1/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.1/node_dist.json: 0.0031745433807373047 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.1/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.1/interarrival_time_dist.json: 0.0027725696563720703 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.1/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.1/flow_size_dist.json: 0.024898529052734375 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.2/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.2/node_dist.json: 0.0011124610900878906 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.2/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.2/interarrival_time_dist.json: 0.0012121200561523438 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.2/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.2/flow_size_dist.json: 0.013692855834960938 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.4/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.4/node_dist.json: 0.0026636123657226562 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.4/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.4/interarrival_time_dist.json: 0.002629995346069336 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.4/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/skewed_nodes_sensitivity_0.4/flow_size_dist.json: 0.025029420852661133 s

# %%
print(plots)
for _class in plots.keys():
    for _dist in plots[_class].keys():
        fig = plots[_class][_dist]
        plt.draw()
        print(type(fig))

plt.show()
# Out:
# {'university': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28f31015e0>, <nxviz.plots.CircosPlot object at 0x7f28f31566d0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'private_enterprise': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28f30e5eb0>, <nxviz.plots.CircosPlot object at 0x7f28f0e68d60>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'commercial_cloud': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28ef920d60>, <nxviz.plots.CircosPlot object at 0x7f28ef814cd0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'social_media_cloud': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28ef30da00>, <nxviz.plots.CircosPlot object at 0x7f28ef190fd0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'skewed_nodes_sensitivity_0.4': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28eee6bb20>, <nxviz.plots.CircosPlot object at 0x7f28eee599a0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}}
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>

# %%
print(dists)
