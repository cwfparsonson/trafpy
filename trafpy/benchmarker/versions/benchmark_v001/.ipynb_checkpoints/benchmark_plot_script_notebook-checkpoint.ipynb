# %%
# %load_ext autoreload
from trafpy.benchmarker.versions.benchmark_v001.distribution_generator import DistributionGenerator

import matplotlib.pyplot as plt

# %%
# %autoreload
import config

distgen = DistributionGenerator(load_prev_dists=True)
for benchmark in config.ALL_BENCHMARK_SETS:
    print(benchmark)
plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['university', 'private_enterprise', 'commercial_cloud', 'social_media_cloud'])
# plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=config.ALL_BENCHMARK_SETS)
# plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['skewed_nodes_sensitivity_{}'.format(i) for i in [0, 0.05, 0.1, 0.2, 0.4]])
# plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['rack_dist_sensitivity_{}'.format(i) for i in [0.2, 0.4, 0.6, 0.8]])
# Out:
# university
# private_enterprise
# commercial_cloud
# social_media_cloud
# uniform
# artificial_light
# skewed_nodes_sensitivity_0
# skewed_nodes_sensitivity_0.05
# skewed_nodes_sensitivity_0.1
# skewed_nodes_sensitivity_0.2
# skewed_nodes_sensitivity_0.4
# rack_dist_sensitivity_0
# rack_dist_sensitivity_0.2
# rack_dist_sensitivity_0.4
# rack_dist_sensitivity_0.6
# rack_dist_sensitivity_0.8
# jobcentric_prototyping
# tensorflow
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/node_dist.json: 0.013189554214477539 s
# Src-dst edge weights in chord diagram are all the same, leading to 0 rescaled values. Decrease chord_edge_display_threshold to ensure a range of edge values are included in the chord diagram.
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/interarrival_time_dist.json: 0.054609060287475586 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/flow_size_dist.json: 0.04581475257873535 s
# num_ops_dist distribution not previously saved in /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/num_ops_dist.json.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-3-7111405b7542> in <module>
#       5 for benchmark in config.ALL_BENCHMARK_SETS:
#       6     print(benchmark)
# ----> 7 plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['uniform', 'university', 'private_enterprise', 'commercial_cloud', 'social_media_cloud'])
#       8 # plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=config.ALL_BENCHMARK_SETS)
#       9 # plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['skewed_nodes_sensitivity_{}'.format(i) for i in [0, 0.05, 0.1, 0.2, 0.4]])
#
# ~/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/distribution_generator.py in plot_benchmark_dists(self, benchmarks)
#     498                 # check loaded dist successfully
#     499                 if dists[benchmark][dist_name] is None:
# --> 500                     raise Exception('Dist {} for benchmark {} not found in {}. Ensure dist is named as one of {}, and that dist has been saved in correct location.'.format(dist_name, benchmark, path_to_data, self.dist_names))
#     501
#     502                 num_demands = max(len(dists[benchmark]['node_dist']) * 1000, 200000) # estimate appropriate number of rand vars to gen
#
# Exception: Dist num_ops_dist for benchmark uniform not found in /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/num_ops_dist.json. Ensure dist is named as one of ['node_dist', 'interarrival_time_dist', 'flow_size_dist', 'num_ops_dist'], and that dist has been saved in correct location.

# %%
print(plots)
for _class in plots.keys():
    for _dist in plots[_class].keys():
        fig = plots[_class][_dist]
        plt.draw()
        print(type(fig))

plt.show()
# Out:
# {'university': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28f31015e0>, <nxviz.plots.CircosPlot object at 0x7f28f31566d0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'private_enterprise': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28f30e5eb0>, <nxviz.plots.CircosPlot object at 0x7f28f0e68d60>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'commercial_cloud': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28ef920d60>, <nxviz.plots.CircosPlot object at 0x7f28ef814cd0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'social_media_cloud': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28ef30da00>, <nxviz.plots.CircosPlot object at 0x7f28ef190fd0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'skewed_nodes_sensitivity_0.4': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28eee6bb20>, <nxviz.plots.CircosPlot object at 0x7f28eee599a0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}}
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>

# %%
print(dists)
