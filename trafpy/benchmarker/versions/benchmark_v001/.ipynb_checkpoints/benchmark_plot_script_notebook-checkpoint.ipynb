# %%
from trafpy.benchmarker.versions.benchmark_v001.distribution_generator import DistributionGenerator

import matplotlib.pyplot as plt

# %%
distgen = DistributionGenerator(load_prev_dists=True)
plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['uniform', 'university'])
# Out:
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/node_dist.json: 0.0015316009521484375 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/interarrival_time_dist.json: 0.0096435546875 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/uniform/flow_size_dist.json: 0.008630752563476562 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/node_dist.json: 0.0009779930114746094 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/interarrival_time_dist.json: 0.0119476318359375 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/university/flow_size_dist.json: 0.010040760040283203 s
# /home/zciccwf/phd_project/projects/trafpy/trafpy/generator/src/dists/plot_dists.py:137: RuntimeWarning: divide by zero encountered in log10
#   logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
# /home/zciccwf/.conda/envs/deep_scheduler/lib/python3.8/site-packages/numpy/core/function_base.py:144: RuntimeWarning: invalid value encountered in multiply
#   y *= step
# /home/zciccwf/.conda/envs/deep_scheduler/lib/python3.8/site-packages/numpy/core/function_base.py:154: RuntimeWarning: invalid value encountered in add
#   y += start

# %%
print(plots)
for _class in plots.keys():
    for _dist in plots[_class].keys():
        fig = plots[_class][_dist]
        print(fig)
        plt.show()
# Out:
# {'uniform': {'node_dist': <matplotlib.image.AxesImage object at 0x7f524f753dc0>, 'interarrival_time_dist': <Figure size 720x1080 with 2 Axes>, 'flow_size_dist': <Figure size 720x1080 with 2 Axes>}, 'university': {'node_dist': <matplotlib.image.AxesImage object at 0x7f524f47ea60>, 'interarrival_time_dist': <Figure size 720x1080 with 2 Axes>, 'flow_size_dist': <Figure size 720x1080 with 2 Axes>}}
# AxesImage(43.2,48.24;178.56x178.56)
# Figure(720x1080)
# Figure(720x1080)
# AxesImage(43.2,48.24;178.56x178.56)
# Figure(720x1080)
# Figure(720x1080)
