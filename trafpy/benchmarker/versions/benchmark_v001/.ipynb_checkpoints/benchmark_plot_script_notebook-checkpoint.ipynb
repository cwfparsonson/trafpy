# %%
# %load_ext autoreload
from trafpy.benchmarker.versions.benchmark_v001.distribution_generator import DistributionGenerator

import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload
import config

distgen = DistributionGenerator(load_prev_dists=True)
for benchmark in config.ALL_BENCHMARK_SETS:
    print(benchmark)
plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['university', 'private_enterprise', 'commercial_cloud', 'social_media_cloud'])
# plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=config.ALL_BENCHMARK_SETS)
# plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['skewed_nodes_sensitivity_{}'.format(i) for i in [0, 0.05, 0.1, 0.2, 0.4]])
# plots, dists, rand_vars = distgen.plot_benchmark_dists(benchmarks=['rack_dist_sensitivity_{}'.format(i) for i in [0.2, 0.4, 0.6, 0.8]])
# Out:
# university
# private_enterprise
# commercial_cloud
# social_media_cloud
# uniform
# artificial_light
# skewed_nodes_sensitivity_0
# skewed_nodes_sensitivity_0.05
# skewed_nodes_sensitivity_0.1
# skewed_nodes_sensitivity_0.2
# skewed_nodes_sensitivity_0.4
# rack_dist_sensitivity_0
# rack_dist_sensitivity_0.2
# rack_dist_sensitivity_0.4
# rack_dist_sensitivity_0.6
# rack_dist_sensitivity_0.8
# jobcentric_prototyping
# tensorflow
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.2/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.2/node_dist.json: 0.006837129592895508 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.2/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.2/interarrival_time_dist.json: 0.006158113479614258 s
# Characteristics of Interarrival Time (μs) distribution: DescribeResult(nobs=200000, minmax=(1.0020620621570604, 9925.0), mean=83.32578972535546, variance=314152.51797503646, skewness=13.028897567368675, kurtosis=179.5748010047477)
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.2/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.2/flow_size_dist.json: 0.009374141693115234 s
# Characteristics of Flow Size (B) distribution: DescribeResult(nobs=200000, minmax=(1.0, 16218675.0), mean=23342.994245, variance=44102319536.044075, skewness=35.488241317503494, kurtosis=1771.7543166007933)
# num_ops_dist distribution not previously saved in /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.2/num_ops_dist.json.
# Dist num_ops_dist for benchmark rack_dist_sensitivity_0.2 not found in /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.2/num_ops_dist.json. Ensure dist is named as one of ['node_dist', 'interarrival_time_dist', 'flow_size_dist', 'num_ops_dist'], and that dist has been saved in correct location.
# Unrecognised dist_name num_ops_dist
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.4/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.4/node_dist.json: 0.023810625076293945 s
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.4/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.4/interarrival_time_dist.json: 0.0219266414642334 s
# Characteristics of Interarrival Time (μs) distribution: DescribeResult(nobs=200000, minmax=(1.0, 10000.0), mean=84.950105, variance=328492.93973018765, skewness=12.989905463931072, kurtosis=179.23444023549365)
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.4/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.4/flow_size_dist.json: 0.05732011795043945 s
# Characteristics of Flow Size (B) distribution: DescribeResult(nobs=200000, minmax=(1.0, 18416850.0), mean=24284.697815, variance=52678705962.94878, skewness=35.45839235902186, kurtosis=1785.9823843536735)
# num_ops_dist distribution not previously saved in /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.4/num_ops_dist.json.
# Dist num_ops_dist for benchmark rack_dist_sensitivity_0.4 not found in /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.4/num_ops_dist.json. Ensure dist is named as one of ['node_dist', 'interarrival_time_dist', 'flow_size_dist', 'num_ops_dist'], and that dist has been saved in correct location.
# Unrecognised dist_name num_ops_dist
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.6/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.6/node_dist.json: 0.04649066925048828 s
# Src-dst edge weights in chord diagram are all the same, leading to 0 rescaled values. Decrease chord_edge_display_threshold to ensure a range of edge values are included in the chord diagram.
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.6/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.6/interarrival_time_dist.json: 0.021448135375976562 s
# Characteristics of Interarrival Time (μs) distribution: DescribeResult(nobs=200000, minmax=(1.0, 9975.0), mean=80.191585, variance=290224.920654791, skewness=13.635934158751766, kurtosis=199.28124036471817)
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.6/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.6/flow_size_dist.json: 0.05679202079772949 s
# Characteristics of Flow Size (B) distribution: DescribeResult(nobs=200000, minmax=(1.0, 18616050.0), mean=22264.84727, variance=36092295173.52322, skewness=36.974593644321764, kurtosis=2130.0343901140304)
# num_ops_dist distribution not previously saved in /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.6/num_ops_dist.json.
# Dist num_ops_dist for benchmark rack_dist_sensitivity_0.6 not found in /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.6/num_ops_dist.json. Ensure dist is named as one of ['node_dist', 'interarrival_time_dist', 'flow_size_dist', 'num_ops_dist'], and that dist has been saved in correct location.
# Unrecognised dist_name num_ops_dist
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.8/node_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.8/node_dist.json: 0.03023552894592285 s
# Src-dst edge weights in chord diagram are all the same, leading to 0 rescaled values. Decrease chord_edge_display_threshold to ensure a range of edge values are included in the chord diagram.
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.8/interarrival_time_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.8/interarrival_time_dist.json: 0.012203693389892578 s
# Characteristics of Interarrival Time (μs) distribution: DescribeResult(nobs=200000, minmax=(1.0124087855188313, 10000.0), mean=82.31513001942547, variance=298520.5723872351, skewness=13.089280580085724, kurtosis=182.58191656258634)
# Loading previously saved benchmark dists from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.8/flow_size_dist.json
# Time to load data from /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.8/flow_size_dist.json: 0.06132102012634277 s
# Characteristics of Flow Size (B) distribution: DescribeResult(nobs=200000, minmax=(1.0, 19972550.0), mean=24224.867875, variance=53930695714.46423, skewness=38.19400452585441, kurtosis=2099.9239228474044)
# num_ops_dist distribution not previously saved in /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.8/num_ops_dist.json.
# Dist num_ops_dist for benchmark rack_dist_sensitivity_0.8 not found in /home/zciccwf/phd_project/projects/trafpy/trafpy/benchmarker/versions/benchmark_v001/data/rack_dist_sensitivity_0.8/num_ops_dist.json. Ensure dist is named as one of ['node_dist', 'interarrival_time_dist', 'flow_size_dist', 'num_ops_dist'], and that dist has been saved in correct location.
# Unrecognised dist_name num_ops_dist

# %%
print(plots)
for _class in plots.keys():
    for _dist in plots[_class].keys():
        fig = plots[_class][_dist]
        plt.draw()
        print(type(fig))

plt.show()
# Out:
# {'university': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28f31015e0>, <nxviz.plots.CircosPlot object at 0x7f28f31566d0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'private_enterprise': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28f30e5eb0>, <nxviz.plots.CircosPlot object at 0x7f28f0e68d60>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'commercial_cloud': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28ef920d60>, <nxviz.plots.CircosPlot object at 0x7f28ef814cd0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'social_media_cloud': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28ef30da00>, <nxviz.plots.CircosPlot object at 0x7f28ef190fd0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}, 'skewed_nodes_sensitivity_0.4': {'node_dist': [<matplotlib.image.AxesImage object at 0x7f28eee6bb20>, <nxviz.plots.CircosPlot object at 0x7f28eee599a0>], 'interarrival_time_dist': <Figure size 1240x200 with 2 Axes>, 'flow_size_dist': <Figure size 1240x200 with 2 Axes>}}
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>
# <class 'list'>
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.figure.Figure'>

# %%
print(dists)
